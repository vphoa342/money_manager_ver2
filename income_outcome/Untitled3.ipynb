# %%
a = 10

# %%
a
# Out:
# 10

# %%
import pandas as pd

data = pd.read_csv('C:\\Users\\Van Phu Hoa\\PycharmProjects\\income_outcome\\{}\\{}_{}.csv'.format('outcome','Jan', 'outcome'))

# %%
data
# Out:
#           Date                          List               Type   Amount
# 0     8/1/2021                  Pho Nam Dinh          necessity    30000
# 1    11/1/2021                  Pho Nam Dinh          necessity    30000
# 2    10/1/2021                      ministop          necessity    61000
# 3   14/01/2021                Hu tieu bo kho          necessity    30000
# 4   14/01/2021                        Xoi ga          necessity    15000
# 5   14/01/2021                  Chicken rice          necessity    25000
# 6   16/01/2021             Gako Chicken Rice          necessity    70000
# 7   16/01/2021           Traditional Milktea          necessity    19000
# 8   19/01/2021                        Xoi ga          necessity    15000
# 9   19/01/2021             Rice rolls + cake          necessity    29000
# 10  21/01/2021                    3 banh gio          necessity    40000
# 11  26/01/2021                      banh gio          necessity    13000
# ...

# %%
data.loc[0]
# Out:
# Date          8/1/2021
# List      Pho Nam Dinh
# Type         necessity
# Amount           30000
# Name: 0, dtype: object
