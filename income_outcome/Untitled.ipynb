# %%
import test.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-421c50460e7f> in <module>
# ----> 1 import test.py
#
# ModuleNotFoundError: No module named 'test.py'

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>
